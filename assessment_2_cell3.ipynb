# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshitha443/ITA-0610-MACHINE-LEARNING-/blob/main/assessment_2_cell3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# CELL 3: Task A3 & Extension (Visualizing Decision Trees)
# ==========================================
import matplotlib.pyplot as plt
from sklearn import tree

fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot Gini Tree
tree.plot_tree(
    model_gini,
    feature_names=X.columns,
    class_names=label_encoders['PlayTennis'].classes_,
    filled=True,
    ax=axes[0]
)
axes[0].set_title("Decision Tree (Gini Index)")

# Plot Entropy Tree
tree.plot_tree(
    model_entropy,
    feature_names=X.columns,
    class_names=label_encoders['PlayTennis'].classes_,
    filled=True,
    ax=axes[1]
)
axes[1].set_title("Decision Tree (Entropy / Information Gain)")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1639/3159415532.py in <cell line: 0>()
#       9 # Plot Gini Tree
#      10 tree.plot_tree(
# ---> 11     model_gini,
#      12     feature_names=X.columns,
#      13     class_names=label_encoders['PlayTennis'].classes_,
#
# NameError: name 'model_gini' is not defined

# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshitha443/ITA-0610-MACHINE-LEARNING-/blob/main/assessment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# cell 2

# %%
import pandas as pd
import numpy as np

# --- Placeholder for Data Loading and Preparation ---
# You will need to replace this with your actual dataset loading and preprocessing.
# For demonstration purposes, we'll create some dummy data.

# Create dummy features (X)
np.random.seed(42) # for reproducibility
data = {
    'Feature1': np.random.rand(100),
    'Feature2': np.random.randint(0, 10, 100),
    'Feature3': np.random.choice(['A', 'B', 'C'], 100)
}
X = pd.DataFrame(data)

# Convert categorical features to numerical (one-hot encode 'Feature3')
X = pd.get_dummies(X, columns=['Feature3'], drop_first=True)

# Create dummy target variable (y)
# Assuming a binary classification problem for simplicity
y = np.random.randint(0, 2, 100)

print("Dummy X (features) head:")
display(X.head())
print("\nDummy y (target) head:")
display(pd.Series(y).head())
# Out:
# Dummy X (features) head:
#    Feature1  Feature2  Feature3_B  Feature3_C
# 0  0.374540         6        True       False
# 1  0.950714         0       False        True
# 2  0.731994         3       False        True
# 3  0.598658         3        True       False
# 4  0.156019         4        True       False
# Dummy y (target) head:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# dtype: int64
